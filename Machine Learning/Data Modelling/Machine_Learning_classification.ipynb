# %% [markdown]
# >Machine learning is a field of AI which allow us to create an intelligent system based on Data.

# %% [markdown]
# ![Different-machine-learning-types-and-algorithms.png](attachment:Different-machine-learning-types-and-algorithms.png)

# %% [markdown]
# >What is supervised learning ?
# Supervised learning is a learning task ,where the model learn from an example.
# In supervised learnind data are labeled.for example emails classification in spam  or no spam ,or sentiments analysis with example of those data is a supervised learning Task.

# %% [markdown]
# ![1_ASYpFfDh7XnreU-ygqXonw.png](attachment:1_ASYpFfDh7XnreU-ygqXonw.png)

# %% [markdown]
# >what is a Regression?
#   we want to map input to a continuous output.
#  https://www.kaggle.com/code/goyalshalini93/car-price-prediction-linear-regression-rfe/data

# %% [markdown]
# >Linear Regression
# Linear regression analysis is used to predict the value of a variable based on the value of another variable. The variable you want to predict is called the dependent variable. The variable you are using to predict the other variable's value is called the independent variable.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
#model function library
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
data=pd.read_csv('Stipend_Data.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 2 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ReserachExperience  30 non-null     float64
#  1   Stipend             30 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 608.0 bytes

# %%
data.describe()
# Out:
#        ReserachExperience        Stipend
# count           30.000000      30.000000
# mean             5.313333   76003.000000
# std              2.837888   27414.429785
# min              1.100000   37731.000000
# 25%              3.200000   56720.750000
# 50%              4.700000   65237.000000
# 75%              7.700000  100544.750000
# max             10.500000  122391.000000

# %%
plt.scatter(data['ReserachExperience'],data['Stipend'])

# %%
x=data['ReserachExperience'].values
y=data['Stipend'].values

# %%
x.shape
# Out:
# (30,)

# %%
x=x.reshape(-1,1)
y=y.reshape(-1,1)
Xtrain,Xtest,Ytrain,Ytest= train_test_split(x,y,test_size = 0.2,random_state=2)

# %%
x.shape
# Out:
# (30, 1)

# %%
model = LinearRegression()
history = model.fit(Xtrain,Ytrain)
train_score = history.score(Xtrain,Ytrain)
test_score = history.score(Xtest,Ytest)

# %%
pred = model.predict(Xtest)
total_pred = model.predict(x)
plt.plot(Xtest,pred)
plt.scatter(Xtest,Ytest,color = "r")
plt.show()
plt.scatter(x,y)
plt.plot(x,total_pred,color = "r")
plt.title("All_Data")
plt.show()

# %% [markdown]
# Exercise
# #search how to do Linear model evaluation?
# try to work with this data
# https://www.kaggle.com/code/goyalshalini93/car-price-prediction-linear-regression-rfe/data

# %% [markdown]
# >what is a Classification?
# we want to map input to output labels

# %% [markdown]
# >Logistic regression is a statistical analysis method to predict a binary outcome, such as yes or no, based on prior observations of a data set.
#
# >Logistic regression is classification algorithm but linear regression is regression algorithm

# %% [markdown]
# ![main-qimg-37d126042d314752b8642f742d0bc109.jpg](attachment:main-qimg-37d126042d314752b8642f742d0bc109.jpg)

# %% [markdown]
# >support vector machine?
# SVM works by mapping data to a high-dimensional feature space so that data points can be categorized, even when the data are not otherwise linearly separable. A separator between the categories is found, then the data are transformed in such a way that the separator could be drawn as a hyperplane.

# %% [markdown]
# ![Screenshot%202022-06-30%20015329.png](attachment:Screenshot%202022-06-30%20015329.png)

# %% [markdown]
# ![Screenshot%202022-06-30%20015443.png](attachment:Screenshot%202022-06-30%20015443.png)

# %% [markdown]
# ![Screenshot%202022-06-30%20015456.png](attachment:Screenshot%202022-06-30%20015456.png)

# %% [markdown]
# ![Screenshot%202022-06-30%20021134.png](attachment:Screenshot%202022-06-30%20021134.png)

# %% [markdown]
# > So we choose the hyperplane so that the distance from it to the nearest data point on each side is maximized. If such a hyperplane exists, it is known as the maximum-margin hyperplane and the linear classifier it defines is known as a maximum-margin classifier; or equivalently, the perceptron of optimal stability.
